# %%
import pandas as pd 
import pathlib

# %%
dirpath = pathlib.Path(r'D:\sadiek\python\projects\python\08.04.2025\CICIFLY-Data-Analytics-Projects-d413f4e\Communicate Data Findings with Ford Bike Sharing Data\Ford_Go_Bike_Dataset\New folder\Data')
files = dirpath.glob('*.csv')

fulldata = []

for f in files :
    read = pd.read_csv(f)
    fulldata.append(read)

    print(f)
# Out:
# D:\sadiek\python\projects\python\08.04.2025\CICIFLY-Data-Analytics-Projects-d413f4e\Communicate Data Findings with Ford Bike Sharing Data\Ford_Go_Bike_Dataset\New folder\Data\201801-fordgobike-tripdata.csv
# D:\sadiek\python\projects\python\08.04.2025\CICIFLY-Data-Analytics-Projects-d413f4e\Communicate Data Findings with Ford Bike Sharing Data\Ford_Go_Bike_Dataset\New folder\Data\201802-fordgobike-tripdata.csv
# D:\sadiek\python\projects\python\08.04.2025\CICIFLY-Data-Analytics-Projects-d413f4e\Communicate Data Findings with Ford Bike Sharing Data\Ford_Go_Bike_Dataset\New folder\Data\201803-fordgobike-tripdata.csv
# D:\sadiek\python\projects\python\08.04.2025\CICIFLY-Data-Analytics-Projects-d413f4e\Communicate Data Findings with Ford Bike Sharing Data\Ford_Go_Bike_Dataset\New folder\Data\201804-fordgobike-tripdata.csv
# ...

# %%
dataframe =   pd.concat(fulldata)

# %%
da
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1863721 entries, 0 to 131362
# Data columns (total 16 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   duration_sec             int64
#  1   start_time               object
#  2   end_time                 object
#  3   start_station_id         float64
#  4   start_station_name       object
#  5   start_station_latitude   float64
#  6   start_station_longitude  float64
#  7   end_station_id           float64
#  8   end_station_name         object
#  9   end_station_latitude     float64
#  10  end_station_longitude    float64
#  11  bike_id                  int64
#  12  user_type                object
#  13  member_birth_year        float64
#  14  member_gender            object
#  15  bike_share_for_all_trip  object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 241.7+ MB

# %%
dataframe = dataframe.drop(columns={'start_station_name','start_station_latitude','end_station_latitude','end_station_longitude'})

# %%
dataframe =  dataframe.dropna()

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=[20,12])
sns.histplot(data=dataframe,x='duration_sec',binrange=[0,3000])
# Out:
# <Axes: xlabel='duration_sec', ylabel='Count'>

# %%
plt.figure(figsize=[20,12])
sns.histplot(data=dataframe,x='duration_min',binrange=[0,80])
# Out:
# <Axes: xlabel='duration_min', ylabel='Count'>

# %%
plt.figure(figsize=[20,12])
sns.histplot(data=dataframe,x='duration_min',binrange=[0,80],hue='member_gender',multiple='stack')
# Out:
# <Axes: xlabel='duration_min', ylabel='Count'>

# %%
dataframe['member_gender'].value_counts()
# Out:
# member_gender
# Male      1279545
# Female     435010
# Other       27001
# Name: count, dtype: int64

# %%
dataframe
# Out:
#         duration_sec                start_time                  end_time  \
# 0              75284  2018-01-31 22:52:35.2390  2018-02-01 19:47:19.8240
# 2              71576  2018-01-31 14:23:55.8890  2018-02-01 10:16:52.1160
# 4              39966  2018-01-31 19:52:24.6670  2018-02-01 06:58:31.0530
# 6                453  2018-01-31 23:53:53.6320  2018-02-01 00:01:26.8050
# 7                180  2018-01-31 23:52:09.9030  2018-01-31 23:55:10.8070
# ...              ...                       ...                       ...
# 131357          1137  2018-12-01 00:01:49.6930  2018-12-01 00:20:47.5190
# 131358           473  2018-12-01 00:11:54.8110  2018-12-01 00:19:48.5470
# 131359           841  2018-12-01 00:02:48.7260  2018-12-01 00:16:49.7660
# 131360           260  2018-12-01 00:05:27.6150  2018-12-01 00:09:47.9560
# 131361           292  2018-12-01 00:03:06.5490  2018-12-01 00:07:59.0800
#
#         start_station_id  start_station_longitude  end_station_id  \
# ...

# %%
weather  = pd.read_excel('weather .xlsx')

# %%
weather
# Out:
#     Month  Climate
# 0       1   Winter
# 1       2   Winter
# 2       3  spring
# 3       4  spring
# 4       5  spring
# 5       6   Summer
# 6       7   Summer
# 7       8   Summer
# 8       9  autumn
# 9      10  autumn
# 10     11  autumn
# 11     12   Winter

# %%
import datetime as dt

# %%
dataframe['start_time']  =  pd.to_datetime(dataframe['start_time'])
# Out:
# C:\Users\mahmoud.sadiek\AppData\Local\Temp\ipykernel_10816\2838585100.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['start_time']  =  pd.to_datetime(dataframe['start_time'])

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1741556 entries, 0 to 131361
# Data columns (total 13 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   duration_sec             int64
#  1   start_time               datetime64[ns]
#  2   end_time                 object
#  3   start_station_id         float64
#  4   start_station_longitude  float64
#  5   end_station_id           float64
#  6   end_station_name         object
#  7   bike_id                  int64
#  8   user_type                object
#  9   member_birth_year        float64
#  10  member_gender            object
#  11  bike_share_for_all_trip  object
#  12  duration_min             float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 186.0+ MB

# %%
dataframe['month'] =   dataframe['start_time'].dt.month
# Out:
# C:\Users\mahmoud.sadiek\AppData\Local\Temp\ipykernel_10816\874028043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataframe['month'] =   dataframe['start_time'].dt.month

# %%
dataframe
# Out:
#         duration_sec              start_time                  end_time  \
# 0              75284 2018-01-31 22:52:35.239  2018-02-01 19:47:19.8240
# 2              71576 2018-01-31 14:23:55.889  2018-02-01 10:16:52.1160
# 4              39966 2018-01-31 19:52:24.667  2018-02-01 06:58:31.0530
# 6                453 2018-01-31 23:53:53.632  2018-02-01 00:01:26.8050
# 7                180 2018-01-31 23:52:09.903  2018-01-31 23:55:10.8070
# ...              ...                     ...                       ...
# 131357          1137 2018-12-01 00:01:49.693  2018-12-01 00:20:47.5190
# 131358           473 2018-12-01 00:11:54.811  2018-12-01 00:19:48.5470
# 131359           841 2018-12-01 00:02:48.726  2018-12-01 00:16:49.7660
# 131360           260 2018-12-01 00:05:27.615  2018-12-01 00:09:47.9560
# 131361           292 2018-12-01 00:03:06.549  2018-12-01 00:07:59.0800
#
#         start_station_id  start_station_longitude  end_station_id  \
# ...

# %%
dataframe =  pd.merge(left=dataframe,right=weather,left_on='month',right_on='Month')

# %%
dataframe
# Out:
#          duration_sec              start_time                  end_time  \
# 0               75284 2018-01-31 22:52:35.239  2018-02-01 19:47:19.8240
# 1               71576 2018-01-31 14:23:55.889  2018-02-01 10:16:52.1160
# 2               39966 2018-01-31 19:52:24.667  2018-02-01 06:58:31.0530
# 3                 453 2018-01-31 23:53:53.632  2018-02-01 00:01:26.8050
# 4                 180 2018-01-31 23:52:09.903  2018-01-31 23:55:10.8070
# ...               ...                     ...                       ...
# 1741551          1137 2018-12-01 00:01:49.693  2018-12-01 00:20:47.5190
# 1741552           473 2018-12-01 00:11:54.811  2018-12-01 00:19:48.5470
# 1741553           841 2018-12-01 00:02:48.726  2018-12-01 00:16:49.7660
# 1741554           260 2018-12-01 00:05:27.615  2018-12-01 00:09:47.9560
# 1741555           292 2018-12-01 00:03:06.549  2018-12-01 00:07:59.0800
#
#          start_station_id  start_station_longitude  end_station_id  \
# ...

# %%
plt.figure(figsize=[20,12])
sns.histplot(data=dataframe,x='duration_sec',hue='Climate',binrange=[0,3000])
# Out:
# <Axes: xlabel='duration_sec', ylabel='Count'>

# %%
plt.figure(figsize=[20,12])
sns.barplot(data=dataframe,x='Climate',y='duration_min',hue='member_gender')
# Out:
# <Axes: xlabel='Climate', ylabel='duration_min'>

# %%
plt.figure(figsize=[20,12])
sns.barplot(data=dataframe,x='Month',y='duration_min')
# Out:
# <Axes: xlabel='Month', ylabel='duration_min'>

# %%
plt.figure(figsize=[20,12])
sns.scatterplot(data=dataframe,x='Month',y='duration_min',hue='user_type')
# Out:
# <Axes: xlabel='Month', ylabel='duration_min'>
# C:\Users\mahmoud.sadiek\AppData\Roaming\Python\Python312\site-packages\IPython\core\events.py:82: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\mahmoud.sadiek\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
