# %%
import pandas as pd 
file =  pd.read_csv('tmdb-movies.csv')

# %%
file   = file.drop(columns={'cast','homepage','director','tagline','keywords','overview','budget_adj','revenue_adj'})

# %%
import numpy as np
file['revenue'] = file['revenue'].replace(0,np.nan)
# Out:
# C:\Users\mahmoud.sadiek\AppData\Local\Temp\ipykernel_24804\3386489115.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file['revenue'] = file['revenue'].replace(0,np.nan)

# %%
file = file.dropna()

# %%
file
# Out:
#            id    imdb_id  popularity       budget       revenue  \
# 0      135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1       76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2      262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3      140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4      168259  tt2820852    9.335014  190000000.0  1.506249e+09
# ...       ...        ...         ...          ...           ...
# 10861      21  tt0060371    0.080598          NaN           NaN
# 10862   20379  tt0060472    0.065543          NaN           NaN
# 10863   39768  tt0060161    0.065141          NaN           NaN
# 10864   21449  tt0061177    0.064317          NaN           NaN
# 10865   22293  tt0060666    0.035919      19000.0           NaN
#
#                      original_title  runtime  \
# 0                    Jurassic World      124
# 1                Mad Max: Fury Road      120
# 2                         Insurgent      119
# ...

# %%
file =  file.dropna()

# %%
file
# Out:
#            id    imdb_id  popularity       budget       revenue  \
# 0      135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1       76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2      262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3      140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4      168259  tt2820852    9.335014  190000000.0  1.506249e+09
# ...       ...        ...         ...          ...           ...
# 10822     396  tt0061184    0.670274    7500000.0  3.373669e+07
# 10828    5780  tt0061107    0.402730    3000000.0  1.300000e+07
# 10829    6644  tt0061619    0.395668    4653000.0  6.000000e+06
# 10835    5923  tt0060934    0.299911   12000000.0  2.000000e+07
# 10848    2161  tt0060397    0.207257    5115000.0  1.200000e+07
#
#                         original_title  runtime  \
# 0                       Jurassic World      124
# 1                   Mad Max: Fury Road      120
# 2                            Insurgent      119
# ...

# %%
import seaborn as sns 
from matplotlib import pyplot as plt 

plt.figure(figsize=[15,9])

sns.lineplot(data=file,x='budget',y='popularity')
# Out:
# <Axes: xlabel='budget', ylabel='popularity'>

# %%
file['popularity'].max()
# Out:
# 32.985763

# %%
file.query(' popularity    == 32.985763 ')
# Out:
#        id    imdb_id  popularity       budget       revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000.0  1.513529e+09  Jurassic World
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15        5562
#
#    vote_average  release_year
# 0           6.5          2015

# %%
file
# Out:
#            id    imdb_id  popularity       budget       revenue  \
# 0      135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1       76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2      262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3      140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4      168259  tt2820852    9.335014  190000000.0  1.506249e+09
# ...       ...        ...         ...          ...           ...
# 10822     396  tt0061184    0.670274    7500000.0  3.373669e+07
# 10828    5780  tt0061107    0.402730    3000000.0  1.300000e+07
# 10829    6644  tt0061619    0.395668    4653000.0  6.000000e+06
# 10835    5923  tt0060934    0.299911   12000000.0  2.000000e+07
# 10848    2161  tt0060397    0.207257    5115000.0  1.200000e+07
#
#                         original_title  runtime  \
# 0                       Jurassic World      124
# 1                   Mad Max: Fury Road      120
# 2                            Insurgent      119
# ...

# %%
file['profit']   =  file['revenue']  -  file['budget']
# Out:
# C:\Users\mahmoud.sadiek\AppData\Local\Temp\ipykernel_24804\1211747429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   file['profit']   =  file['revenue']  -  file['budget']

# %%
file
# Out:
#            id    imdb_id  popularity       budget       revenue  \
# 0      135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1       76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2      262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3      140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4      168259  tt2820852    9.335014  190000000.0  1.506249e+09
# ...       ...        ...         ...          ...           ...
# 10822     396  tt0061184    0.670274    7500000.0  3.373669e+07
# 10828    5780  tt0061107    0.402730    3000000.0  1.300000e+07
# 10829    6644  tt0061619    0.395668    4653000.0  6.000000e+06
# 10835    5923  tt0060934    0.299911   12000000.0  2.000000e+07
# 10848    2161  tt0060397    0.207257    5115000.0  1.200000e+07
#
#                         original_title  runtime  \
# 0                       Jurassic World      124
# 1                   Mad Max: Fury Road      120
# 2                            Insurgent      119
# ...

# %%
plt.figure(figsize=[15,9])

sns.regplot(data=file,y='revenue',x='popularity')
# Out:
# <Axes: xlabel='popularity', ylabel='revenue'>

# %%
top10  =  file.nlargest(10,'revenue')

# %%
top10.hist(figsize=[15,9])
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'budget'}>],
#        [<Axes: title={'center': 'revenue'}>,
#         <Axes: title={'center': 'runtime'}>,
#         <Axes: title={'center': 'vote_count'}>],
#        [<Axes: title={'center': 'vote_average'}>,
#         <Axes: title={'center': 'release_year'}>,
#         <Axes: title={'center': 'profit'}>]], dtype=object)

# %%
top10
# Out:
#           id    imdb_id  popularity       budget       revenue  \
# 1386   19995  tt0499549    9.432768  237000000.0  2.781506e+09
# 3     140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 5231     597  tt0120338    4.355219  200000000.0  1.845034e+09
# 4361   24428  tt0848228    7.637767  220000000.0  1.519558e+09
# 0     135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 4     168259  tt2820852    9.335014  190000000.0  1.506249e+09
# 14     99861  tt2395427    5.944927  280000000.0  1.405036e+09
# 3374   12445  tt1201607    5.711315  125000000.0  1.327818e+09
# 5422  109445  tt2294629    6.112766  150000000.0  1.274219e+09
# 5425   68721  tt1300854    4.946136  200000000.0  1.215440e+09
#
#                                     original_title  runtime  \
# 1386                                        Avatar      162
# 3                     Star Wars: The Force Awakens      136
# 5231                                       Titanic      194
# ...

# %%
file
# Out:
#            id    imdb_id  popularity       budget       revenue  \
# 0      135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1       76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2      262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3      140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4      168259  tt2820852    9.335014  190000000.0  1.506249e+09
# ...       ...        ...         ...          ...           ...
# 10822     396  tt0061184    0.670274    7500000.0  3.373669e+07
# 10828    5780  tt0061107    0.402730    3000000.0  1.300000e+07
# 10829    6644  tt0061619    0.395668    4653000.0  6.000000e+06
# 10835    5923  tt0060934    0.299911   12000000.0  2.000000e+07
# 10848    2161  tt0060397    0.207257    5115000.0  1.200000e+07
#
#                         original_title  runtime  \
# 0                       Jurassic World      124
# 1                   Mad Max: Fury Road      120
# 2                            Insurgent      119
# ...

# %%
file['genres'].str.split('|',n=7,expand=True)
# Out:
#                0                1                2         3        4
# 0         Action        Adventure  Science Fiction  Thriller     None
# 1         Action        Adventure  Science Fiction  Thriller     None
# 2      Adventure  Science Fiction         Thriller      None     None
# 3         Action        Adventure  Science Fiction   Fantasy     None
# 4         Action            Crime         Thriller      None     None
# ...          ...              ...              ...       ...      ...
# 10822      Drama             None             None      None     None
# 10828    Mystery         Thriller             None      None     None
# 10829     Action          Western             None      None     None
# 10835     Action        Adventure            Drama       War  Romance
# 10848  Adventure  Science Fiction             None      None     None
#
# [3809 rows x 5 columns]

# %%
d1 =  file.copy()
d2 =  file.copy()
d3 =  file.copy()
d4 =  file.copy()
d5 =  file.copy()

# %%
splitcolumn =  ['genres']

for i in splitcolumn:
    d1[i] = file[i].str.split('|',n=7,expand=True)[0]
    d2[i] = file[i].str.split('|',n=7,expand=True)[1]
    d3[i] = file[i].str.split('|',n=7,expand=True)[2]
    d4[i] = file[i].str.split('|',n=7,expand=True)[3]
    d5[i] = file[i].str.split('|',n=7,expand=True)[4]

# %%
d1 = d1.dropna()
d2 = d2.dropna()
d3 = d3.dropna()
d4 = d4.dropna()
d5 = d5.dropna()

# %%
d5.isna().sum()
# Out:
# id                         0
# imdb_id                    0
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# runtime                    0
# genres                  3553
# production_companies       0
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# profit                     0
# dtype: int64

# %%
d5
# Out:
#            id    imdb_id  popularity       budget      revenue  \
# 20     158852  tt1964418    5.462138  190000000.0  209035668.0
# 37     105864  tt1979388    3.339135  175000000.0  331926147.0
# 38     241554  tt2199571    3.237370   50000000.0   71561644.0
# 46     228161  tt2224026    2.976436  135000000.0  368871007.0
# 49     254320  tt3464902    2.885126    4000000.0    9064511.0
# ...       ...        ...         ...          ...          ...
# 10539   10017  tt0092240    0.347800    2700000.0    3500000.0
# 10656   11165  tt0066473    0.381352   25485000.0   29548291.0
# 10683    5185  tt0066249    0.429246   10000000.0    1500000.0
# 10788   24961  tt0078504    0.277769   24000000.0   21049053.0
# 10835    5923  tt0060934    0.299911   12000000.0   20000000.0
#
#                             original_title  runtime           genres  \
# 20                            Tomorrowland      130          Mystery
# ...

# %%
newfile =  pd.concat([d1,d2,d3,d4,d5])

# %%
newfile
# Out:
#            id    imdb_id  popularity       budget       revenue  \
# 0      135397  tt0369610   32.985763  150000000.0  1.513529e+09
# 1       76341  tt1392190   28.419936  150000000.0  3.784364e+08
# 2      262500  tt2908446   13.112507  110000000.0  2.952382e+08
# 3      140607  tt2488496   11.173104  200000000.0  2.068178e+09
# 4      168259  tt2820852    9.335014  190000000.0  1.506249e+09
# ...       ...        ...         ...          ...           ...
# 10539   10017  tt0092240    0.347800    2700000.0  3.500000e+06
# 10656   11165  tt0066473    0.381352   25485000.0  2.954829e+07
# 10683    5185  tt0066249    0.429246   10000000.0  1.500000e+06
# 10788   24961  tt0078504    0.277769   24000000.0  2.104905e+07
# 10835    5923  tt0060934    0.299911   12000000.0  2.000000e+07
#
#                             original_title  runtime           genres  \
# 0                           Jurassic World      124           Action
# ...

# %%
plt.figure(figsize=[20,9])

sns.barplot(data=newfile,x='release_year',y='popularity',hue='genres')
# Out:
# <Axes: xlabel='release_year', ylabel='popularity'>
