# %%
import pandas as pd 
import pathlib


data2008  = pd.read_csv(pathlib.Path(r'D:\sadiek\python\projects\python\08.04.2025\CICIFLY-Data-Analytics-Projects-d413f4e\Data Analytics with Fuel Economy Data\Fuel_Economy_Data\all_alpha_08.csv'))
data20018 = pd.read_csv(pathlib.Path(r'D:\sadiek\python\projects\python\08.04.2025\CICIFLY-Data-Analytics-Projects-d413f4e\Data Analytics with Fuel Economy Data\Fuel_Economy_Data\all_alpha_18.csv'))

# %%
data20018 = pd.read_csv(pathlib.Path(r'D:\sadiek\python\projects\python\08.04.2025\CICIFLY-Data-Analytics-Projects-d413f4e\Data Analytics with Fuel Economy Data\Fuel_Economy_Data\all_alpha_18.csv'))

# %%
data20018
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert Region       Stnd            Stnd Description  Underhood ID  \
# ...

# %%
data2008
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
data2008  = data2008.drop(columns={'Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG'})

# %%
data2008
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA
# ...           ...    ...      ...      ...   ...       ...        ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA
#
#         Veh Class Air Pollution Score City MPG Hwy MPG Cmb MPG  \
# ...

# %%
data20018 = data20018.drop(columns={'Stnd', 'Stnd Description', 'Underhood ID', 'Comb CO2'})

# %%
data2008    =   data2008.rename(columns={'Sales Area':'Cert Region'})

# %%
data2008
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Cert Region  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          FA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          FA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# ...           ...    ...      ...      ...   ...       ...         ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          CA
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          FA
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          FA
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          FA
#
#         Veh Class Air Pollution Score City MPG Hwy MPG Cmb MPG  \
# ...

# %%
data2008.columns =   data20018.columns.str.replace(' ','_')

# %%
data2008
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Cert Region  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          FA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          FA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# ...           ...    ...      ...      ...   ...       ...         ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          CA
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          FA
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          FA
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          FA
#
#         Veh Class Air Pollution Score City MPG Hwy MPG Cmb MPG  \
# ...

# %%
data2008.query(''Cert Region' == 'CA'  ')
# Out:
#   Cell In[62], line 1
#     data2008.query(''Cert Region' == 'CA'  ')
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
data20018.columns =  data20018.columns.str.replace(' ','_')

# %%
data2008
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Cert_Region  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          FA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          FA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# ...           ...    ...      ...      ...   ...       ...         ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          CA
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          FA
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          FA
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          FA
#
#         Veh_Class Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
cal2008 =   data2008.query('  Cert_Region == "CA"    ')

# %%
data2008[data2008['Cert_Region'] == "CA"]
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Cert_Region  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 6        ACURA TL    3.2  (6 cyl)  Auto-S5   2WD  Gasoline          CA
# 7        ACURA TL    3.5  (6 cyl)  Auto-S5   2WD  Gasoline          CA
# ...           ...    ...      ...      ...   ...       ...         ...
# 2394    VOLVO V70    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          CA
# 2396  VOLVO XC 70    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2398  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          CA
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          CA
#
#           Veh_Class Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
data2008.query('  Cert_Region == "CA"   & Veh_Class == "SUV" ')
# Out:
#                    Model  Displ      Cyl    Trans Drive      Fuel Cert_Region  \
# 0              ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline          CA
# 2              ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline          CA
# 63               AUDI Q7    3.6  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 65               AUDI Q7    4.2  (8 cyl)  Auto-S6   4WD  Gasoline          CA
# 230               BMW X3    3.0  (6 cyl)    Man-6   4WD  Gasoline          CA
# ...                  ...    ...      ...      ...   ...       ...         ...
# 2334  VOLKSWAGEN Touareg    4.2  (8 cyl)  Auto-S6   4WD  Gasoline          CA
# 2396         VOLVO XC 70    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2398         VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline          CA
# 2399         VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline          CA
# 2400         VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline          CA
#
# ...

# %%
cal2018  =   data20018.query(' Cert_Region == "CA" ')

# %%
cal2008 =  cal2008.dropna()

# %%
cal2018 =  cal2018.dropna()

# %%
cal2018 =  cal2018.drop_duplicates()

# %%
cal2008 =  cal2008.drop_duplicates()

# %%
data2008['Cyl'] = data2008['Cyl'].str.extract('(\d+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\mahmoud.sadiek\AppData\Local\Temp\ipykernel_2444\39442589.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data2008['Cyl'] = data2008['Cyl'].str.extract('(\d+)')

# %%
import numpy as np
data2008['Cyl'] =  data2008['Cyl'].astype('Int64')

# %%
data2008['Cyl'].value_counts()
# Out:
# Cyl
# 6     864
# 4     600
# 8     533
# 5     113
# 12     60
# 10     29
# 2       4
# 16      2
# Name: count, dtype: int64

# %%
data2008.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                       Int64
# Trans                    object
# Drive                    object
# Fuel                     object
# Cert_Region              object
# Veh_Class                object
# Air_Pollution_Score      object
# City_MPG                 object
# Hwy_MPG                  object
# Cmb_MPG                  object
# Greenhouse_Gas_Score     object
# SmartWay                 object
# dtype: object

# %%
data2008.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                       Int64
# Trans                    object
# Drive                    object
# Fuel                     object
# Cert_Region              object
# Veh_Class                object
# Air_Pollution_Score      object
# City_MPG                 object
# Hwy_MPG                  object
# Cmb_MPG                  object
# Greenhouse_Gas_Score     object
# SmartWay                 object
# dtype: object

# %%
data2008['Air_Pollution_Score'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       7
# 1       6
# 2       7
# 3       6
# 4       7
#        ..
# 2399    7
# 2400    7
# 2401    6
# 2402    6
# 2403    6
# Name: Air_Pollution_Score, Length: 2404, dtype: object>

# %%
cal2018[cal2018['City_MPG'].str.contains('/')]
# Out:
#                                   Model  Displ  Cyl       Trans Drive  \
# 108                            BMW 330e    2.0  4.0  SemiAuto-8   2WD
# 160                            BMW 530e    2.0  4.0  SemiAuto-8   2WD
# 162                            BMW 530e    2.0  4.0  SemiAuto-8   4WD
# 188                            BMW 740e    2.0  4.0  SemiAuto-8   4WD
# 382                    CHEVROLET Impala    3.6  6.0  SemiAuto-6   2WD
# 394              CHEVROLET Silverado 15    4.3  6.0      Auto-6   2WD
# 396              CHEVROLET Silverado 15    4.3  6.0      Auto-6   4WD
# 398              CHEVROLET Silverado 15    5.3  8.0      Auto-6   2WD
# 428             CHEVROLET Suburban 1500    5.3  8.0      Auto-6   2WD
# 432             CHEVROLET Suburban 1500    5.3  8.0      Auto-6   4WD
# 436                CHEVROLET Tahoe 1500    5.3  8.0      Auto-6   2WD
# 440                CHEVROLET Tahoe 1500    5.3  8.0      Auto-6   4WD
# ...

# %%
filter1 =  cal2018pre.copy()
filter2 =  cal2018pre.copy()

# %%
cal2018pre =  cal2018.copy()

# %%
splitedcolumns =  ['Fuel','City_MPG','Hwy_MPG','Cmb_MPG']

# %%
for c in splitedcolumns:
    filter1[c] =  cal2018pre[c].str.split('/',n=1,expand=True)[0]
    filter2[c] =  cal2018pre[c].str.split('/',n=1,expand=True)[1]

# %%
cal2018pre
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 108      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 109      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 160      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 161      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 162      BMW 530e    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# ...           ...    ...  ...         ...   ...                   ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert_Region     Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
filter1
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD       NaN          CA
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD       NaN          CA
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD       NaN          CA
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD       NaN          CA
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD       NaN          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1603  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD       NaN          CA
# 1605  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD       NaN          CA
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD       NaN          CA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
#
#          Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
filter2
# Out:
#             Model  Displ  Cyl       Trans Drive         Fuel Cert_Region  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD          NaN          CA
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD          NaN          CA
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD          NaN          CA
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD          NaN          CA
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD          NaN          CA
# ...           ...    ...  ...         ...   ...          ...         ...
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Electricity          CA
# 1603  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD          NaN          CA
# 1605  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD          NaN          CA
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD          NaN          CA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Electricity          CA
#
#          Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
cal2018pre =  data20018[data20018['City_MPG'].str.contains('/')]

# %%
for c in splitedcolumns:
    filter1[c] =  cal2018pre[c].str.split('/',n=1,expand=True)[0]
    filter2[c] =  cal2018pre[c].str.split('/',n=1,expand=True)[1]

# %%
filter2 = cal2018pre.copy()

# %%
filter1
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 108      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Gasoline          CA
# 109      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Gasoline          FA
# 160      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Gasoline          CA
# 161      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Gasoline          FA
# 162      BMW 530e    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
#
#          Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
filter2
# Out:
#             Model  Displ  Cyl       Trans Drive         Fuel Cert_Region  \
# 108      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Electricity          CA
# 109      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Electricity          FA
# 160      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Electricity          CA
# 161      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Electricity          FA
# 162      BMW 530e    2.0  4.0  SemiAuto-8   4WD  Electricity          CA
# ...           ...    ...  ...         ...   ...          ...         ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Electricity          FA
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Electricity          CA
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Electricity          FA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Electricity          CA
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Electricity          FA
#
#          Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
cal2018pre
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 108      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 109      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 160      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 161      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 162      BMW 530e    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# ...           ...    ...  ...         ...   ...                   ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert_Region     Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
cal2018pre
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 108      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 109      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 160      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 161      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Gasoline/Electricity
# 162      BMW 530e    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# ...           ...    ...  ...         ...   ...                   ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert_Region     Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
cal2018 = cal2018.drop(drop,axis=0)

# %%
cal2018.drop(drop,axis=0)
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline          CA
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1597  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1599  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1603  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD  Gasoline          CA
# 1605  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
#
#          Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
cal2018
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD              Gasoline
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1603  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD              Gasoline
# 1605  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert_Region     Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
drop   = cal2018[cal2018['Hwy_MPG'].str.contains('/')].index

# %%
drop
# Out:
# Index([ 108,  160,  162,  188,  382,  394,  396,  398,  428,  432,  436,  440,
#         454,  456,  458,  462,  492,  496,  605,  659,  661,  663,  697,  701,
#         709,  715,  892,  896,  933, 1162, 1179, 1192, 1256, 1507, 1517, 1577,
#        1601, 1609],
#       dtype='int64')

# %%
cal2018
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD              Gasoline
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1603  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD              Gasoline
# 1605  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert_Region     Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
cal2018
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline          CA
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1597  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1599  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1603  VOLVO XC 90    2.0  4.0  SemiAuto-8   2WD  Gasoline          CA
# 1605  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
#
#          Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
filter1
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 108      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Gasoline          CA
# 109      BMW 330e    2.0  4.0  SemiAuto-8   2WD  Gasoline          FA
# 160      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Gasoline          CA
# 161      BMW 530e    2.0  4.0  SemiAuto-8   2WD  Gasoline          FA
# 162      BMW 530e    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
#
#          Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
new =  pd.concat([cal2018,filter2,filter1])

# %%
new
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline          CA
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
#
#          Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
new.hist(figsize=[25,12])
# Out:
# array([[<Axes: title={'center': 'Displ'}>,
#         <Axes: title={'center': 'Cyl'}>],
#        [<Axes: title={'center': 'Air_Pollution_Score'}>,
#         <Axes: title={'center': 'Greenhouse_Gas_Score'}>]], dtype=object)

# %%
data2008.hist(figsize=[20,13])
# Out:
# array([[<Axes: title={'center': 'Displ'}>,
#         <Axes: title={'center': 'Cyl'}>]], dtype=object)

# %%
data2008.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                       Int64
# Trans                    object
# Drive                    object
# Fuel                     object
# Cert_Region              object
# Veh_Class                object
# Air_Pollution_Score      object
# City_MPG                 object
# Hwy_MPG                  object
# Cmb_MPG                  object
# Greenhouse_Gas_Score     object
# SmartWay                 object
# dtype: object

# %%
data2008.dtypes
# Out:
# Model                    object
# Displ                   float64
# Cyl                       Int64
# Trans                    object
# Drive                    object
# Fuel                     object
# Cert_Region              object
# Veh_Class                object
# Air_Pollution_Score      object
# City_MPG                 object
# Hwy_MPG                  object
# Cmb_MPG                  object
# Greenhouse_Gas_Score     object
# SmartWay                 object
# dtype: object

# %%
cal2008['Air_Pollution_Score'] =  cal2008['Air_Pollution_Score'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[210], line 1
# ----> 1 cal2008['Air_Pollution_Score'] =  cal2008['Air_Pollution_Score'].astype(float)
#
# File c:\Users\mahmoud.sadiek\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File c:\Users\mahmoud.sadiek\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
drop  = cal2008[cal2008['Air_Pollution_Score'].str.contains('/')].index

# %%
cal2008 = cal2008.drop(drop)

# %%
cal2008
# Out:
#             Model  Displ  Cyl    Trans Drive      Fuel Cert_Region  \
# 0       ACURA MDX    3.7    6  Auto-S5   4WD  Gasoline          CA
# 2       ACURA RDX    2.3    4  Auto-S5   4WD  Gasoline          CA
# 4        ACURA RL    3.5    6  Auto-S5   4WD  Gasoline          CA
# 6        ACURA TL    3.2    6  Auto-S5   2WD  Gasoline          CA
# 7        ACURA TL    3.5    6  Auto-S5   2WD  Gasoline          CA
# ...           ...    ...  ...      ...   ...       ...         ...
# 2394    VOLVO V70    3.2    6  Auto-S6   2WD  Gasoline          CA
# 2396  VOLVO XC 70    3.2    6  Auto-S6   4WD  Gasoline          CA
# 2398  VOLVO XC 90    3.2    6  Auto-S6   2WD  Gasoline          CA
# 2399  VOLVO XC 90    3.2    6  Auto-S6   4WD  Gasoline          CA
# 2400  VOLVO XC 90    4.4    8  Auto-S6   4WD  Gasoline          CA
#
#           Veh_Class Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# 0               SUV                   7       15      20      17
# ...

# %%
cal2008['Greenhouse_Gas_Score'] =  cal2008['Greenhouse_Gas_Score'].astype(int)

# %%
cal2008.hist(figsize=[15,8])
# Out:
# array([[<Axes: title={'center': 'Displ'}>,
#         <Axes: title={'center': 'Cyl'}>,
#         <Axes: title={'center': 'Air_Pollution_Score'}>],
#        [<Axes: title={'center': 'City_MPG'}>,
#         <Axes: title={'center': 'Hwy_MPG'}>,
#         <Axes: title={'center': 'Cmb_MPG'}>],
#        [<Axes: title={'center': 'Greenhouse_Gas_Score'}>, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
new.hist()
# Out:
# array([[<Axes: title={'center': 'Displ'}>,
#         <Axes: title={'center': 'Cyl'}>],
#        [<Axes: title={'center': 'Air_Pollution_Score'}>,
#         <Axes: title={'center': 'Greenhouse_Gas_Score'}>]], dtype=object)

# %%
new
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline          CA
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
#
#          Veh_Class  Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
new['Greenhouse_Gas_Score'] =  new['Greenhouse_Gas_Score'].astype(int)

# %%
new.hist(figsize=[20,13])
# Out:
# array([[<Axes: title={'center': 'Displ'}>,
#         <Axes: title={'center': 'Cyl'}>],
#        [<Axes: title={'center': 'Air_Pollution_Score'}>,
#         <Axes: title={'center': 'City_MPG'}>],
#        [<Axes: title={'center': 'Hwy_MPG'}>,
#         <Axes: title={'center': 'Greenhouse_Gas_Score'}>]], dtype=object)

# %%
cal2008.hist(figsize=[15,6])
new.hist(figsize=[15,6])
# Out:
# array([[<Axes: title={'center': 'Displ'}>,
#         <Axes: title={'center': 'Cyl'}>],
#        [<Axes: title={'center': 'Air_Pollution_Score'}>,
#         <Axes: title={'center': 'City_MPG'}>],
#        [<Axes: title={'center': 'Hwy_MPG'}>,
#         <Axes: title={'center': 'Greenhouse_Gas_Score'}>]], dtype=object)

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=[20,10])
sns.boxenplot(data=new)
# Out:
# <Axes: >

# %%
new
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline          CA
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
#
#          Veh_Class  Air_Pollution_Score  City_MPG  Hwy_MPG Cmb_MPG  \
# ...

# %%
sns.pairplot(data=new)

# %%
new['year'] =  '2018'

# %%
new
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          CA
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD  Gasoline          CA
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD  Gasoline          CA
# 6       ACURA TLX    3.5  6.0  SemiAuto-9   2WD  Gasoline          CA
# 8       ACURA TLX    3.5  6.0  SemiAuto-9   4WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
#
#          Veh_Class  Air_Pollution_Score  City_MPG  Hwy_MPG Cmb_MPG  \
# ...

# %%
data2008['year'] = '2008'

# %%
totaldata =  pd.concat([data2008,new])

# %%
totaldata
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 0       ACURA MDX    3.7  6.0     Auto-S5   4WD  Gasoline          CA
# 1       ACURA MDX    3.7  6.0     Auto-S5   4WD  Gasoline          FA
# 2       ACURA RDX    2.3  4.0     Auto-S5   4WD  Gasoline          CA
# 3       ACURA RDX    2.3  4.0     Auto-S5   4WD  Gasoline          FA
# 4        ACURA RL    3.5  6.0     Auto-S5   4WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
#
#          Veh_Class Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
plt.figure(figsize=[12,15])
sns.boxenplot(data=totaldata,y =  'City_MPG' ,hue='year')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[282], line 2
#       1 plt.figure(figsize=[12,15])
# ----> 2 sns.boxenplot(data=totaldata,y =  'City_MPG' ,hue='year')
#
# File c:\Users\mahmoud.sadiek\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:1921, in boxenplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, linewidth, linecolor, width_method, k_depth, outlier_prop, trust_alpha, showfliers, hue_norm, log_scale, native_scale, formatter, legend, scale, box_kws, flier_kws, line_kws, ax, **kwargs)
#    1918 if p.var_types.get(p.orient) == "categorical" or not native_scale:
#    1919     p.scale_categorical(p.orient, order=order, formatter=formatter)
# -> 1921 p._attach(ax, log_scale=log_scale)
#    1923 # Deprecations to remove in v0.14.0.
# ...

# %%
totaldata
# Out:
#             Model  Displ  Cyl       Trans Drive      Fuel Cert_Region  \
# 0       ACURA MDX    3.7  6.0     Auto-S5   4WD  Gasoline          CA
# 1       ACURA MDX    3.7  6.0     Auto-S5   4WD  Gasoline          FA
# 2       ACURA RDX    2.3  4.0     Auto-S5   4WD  Gasoline          CA
# 3       ACURA RDX    2.3  4.0     Auto-S5   4WD  Gasoline          FA
# 4        ACURA RL    3.5  6.0     Auto-S5   4WD  Gasoline          CA
# ...           ...    ...  ...         ...   ...       ...         ...
# 1578    VOLVO S90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1601  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1602  VOLVO XC 60    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          CA
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline          FA
#
#          Veh_Class Air_Pollution_Score City_MPG Hwy_MPG Cmb_MPG  \
# ...

# %%
totaldata[totaldata['SmartWay'].str.contains('/')]
# Out:
# Empty DataFrame
# Columns: [Model, Displ, Cyl, Trans, Drive, Fuel, Cert_Region, Veh_Class, Air_Pollution_Score, City_MPG, Hwy_MPG, Cmb_MPG, Greenhouse_Gas_Score, SmartWay, year]
# Index: []
